# %% [markdown]
# lets go baby////
# ![banner-3 (2).jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import tqdm.notebook as tqdm

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-74cp5j4i
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-74cp5j4i
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 99050710d78b22b5c605b08d85c1513d9db44323
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter

# %%
scraper = sntwitter.TwitterSearchScraper('ukrainewar')

# %%
for tweet in scraper.get_items():
  break

# %%
tweet
# Out:
# Tweet(url='https://twitter.com/OjefChJLrbqC7cu/status/1632276025483874304', date=datetime.datetime(2023, 3, 5, 7, 5, 5, tzinfo=datetime.timezone.utc), rawContent='"ビッグブラザーが帰ってきた"：オラフ・ショルツ首相の訪米を伝えるドイツ誌Sternのカバーストーリー\n\n"バイデンがいるのは幸運です-ロシアと中国との対立で、私たちは再び米国に頼ることができます "とキャプションに書かれています。\n\n#ウクライナ侵攻 \n#UkraineWar \n#Ukraine https://t.co/WFraKvygpz', renderedContent='"ビッグブラザーが帰ってきた"：オラフ・ショルツ首相の訪米を伝えるドイツ誌Sternのカバーストーリー\n\n"バイデンがいるのは幸運です-ロシアと中国との対立で、私たちは再び米国に頼ることができます "とキャプションに書かれています。\n\n#ウクライナ侵攻 \n#UkraineWar \n#Ukraine https://t.co/WFraKvygpz', id=1632276025483874304, user=User(username='OjefChJLrbqC7cu', id=1507200267884072960, displayname='ウクライナに栄光あれ', rawDescription='', renderedDescription='', descriptionLinks=None, verified=False, created=datetime.datetime(2022, 3, 25, 3, 39, 45, tzinfo=datetime.timezone.utc), followersCount=1644, friendsCount=274, statusesCount=21725, favouritesCount=7883, listedCount=47, mediaCount=17597, location='', protected=False, link=None, profileImageUrl='https
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Created a list to append all tweet attributes(data)
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#ukrainewar').get_items()):
    if i>10000:
        break
    attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content, tweet.user.username,
      tweet.likeCount,
      tweet.retweetCount])
    
# Creating a dataframe from the tweets list above 
tweets_df = pd.DataFrame(attributes_container, columns=["Date Created", "Number of Likes", "Source of Tweet", "Tweets","username","like_Count","retweet_Count"])
# Out:
# <ipython-input-37-2ceabd8cfc92>:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content, tweet.user.username,

# %%
tweets_df.head()
# Out:
#                Date Created  Number of Likes     Source of Tweet  \
# 0 2023-03-05 09:04:20+00:00                0     Twitter Web App
# 1 2023-03-05 09:04:20+00:00                1     Twitter Web App
# 2 2023-03-05 09:03:51+00:00                0     Twitter Web App
# 3 2023-03-05 09:03:41+00:00                1  Twitter for iPhone
# 4 2023-03-05 09:02:44+00:00                0     Twitter Web App
#
#                                               Tweets         username  \
# 0  Ukrainians decimate Russian troops in Kherson ...        HiHikeep4
# 1  [ Bakhmut ] Mass Ukrainian Withdrawal NOW Unde...  DefensePolitics
# 2  #China considering lethal aid to #Russia : Pen...   LaurentOpsomer
# 3  🇷🇺”Lancet" kamikaze drone strikes a Ukrainian ...        Zagonel85
# 4  "War is peace, freedom is slavery, ignorance i...   TrancherCasual
#
#    like_Count  retweet_Count
# 0           0              0
# 1           1              0
# 2           0              0
# 3           1              0
# ...

# %%
tweets_df.to_csv("ukaraine.csv1",index=False)
